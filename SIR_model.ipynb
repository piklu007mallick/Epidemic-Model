# %% [markdown]
# <a href="https://colab.research.google.com/github/piklu007mallick/Epidemic-Model/blob/main/SIR_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from scipy.integrate import odeint
import numpy as np

# %%
def dU_dt(U, t):
 return [-alpha*U[0]*U[1], alpha*U[0]*U[1]-mu*U[1], mu*U[1]]

# %%
#Initial Condition
U0=[1500,1,0]

# %%
alpha, mu = 0.005, 0.1

# %%
ts= np.arange(0,60, 1)

# %%
Us= odeint(dU_dt, U0, ts)
S, I, R = Us[:,0], Us[:,1], Us[:,2]

# %%
import matplotlib.pyplot as plt
fig=plt.subplots(figsize=(12, 10))
plt.plot(ts, S, linewidth=2.5, label='Susceptible')
plt.plot(ts, I, linewidth=2.5, label='Infected')
plt.plot(ts, R, linewidth=2.5, label='Recovered')
plt.legend()
